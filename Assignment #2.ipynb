# %%
open("The Meadow-Tom Sleigh").read()
# Out:
# 'Across the road from where we nap\nunder a dead elm dazzles the meadow\nwhere the partisans strung the traitors up,\n\nthe meadow which their dangling shadows stain.\nBelly up in vines a blasted tank\nrusts flake by flake to lichened scrap iron\n\nwhile horseflies harangue\nthe rippling green, July\na limbo of quavering yellow...\n\nWe wake to cattle lowing at dawn,\ngrass overgrowing summer—so like us\nin love each hour with the noonday sun\n\nthat neither toils nor spins, its brightness\nhovering, blinding us...\nWhat would the dead say if they could see us,\n\nlounging, talking, peering through brambles\nat cemetery photographs sunk beneath\nthe undertow of milkweed shadows,\n\ndeath dates smoothing back into the stone?\nI think of Goya’s demon, old man flesh\nhanging from his bones, long teeth bared in\n\nan ass’s grin as he scrawls on a schoolboy’s\nslate, What more can be done? Nothing...\nwhile behind him a noose etched clean as\n\nthe moon rises through the inkblot\nspiralin
# ...

# %%
human = "옷"

# %%
human
# Out:
# '옷'

# %%
poem = open("The Meadow-Tom Sleigh").read()

# %%
print(poem)
# Out:
# Across the road from where we nap
# under a dead elm dazzles the meadow
# where the partisans strung the traitors up,
#
# the meadow which their dangling shadows stain.
# Belly up in vines a blasted tank
# rusts flake by flake to lichened scrap iron
#
# while horseflies harangue
# the rippling green, July
# a limbo of quavering yellow...
#
# We wake to cattle lowing at dawn,
# grass overgrowing summer—so like us
# in love each hour with the noonday sun
#
# that neither toils nor spins, its brightness
# hovering, blinding us...
# What would the dead say if they could see us,
#
# lounging, talking, peering through brambles
# at cemetery photographs sunk beneath
# the undertow of milkweed shadows,
#
# death dates smoothing back into the stone?
# I think of Goya’s demon, old man flesh
# hanging from his bones, long teeth bared in
#
# an ass’s grin as he scrawls on a schoolboy’s
# slate, What more can be done? Nothing...
# while behind him a noose etched clean as
#
# ...

# %%
print(poem.replace("we ", "옷 "))
# Out:
# Across the road from where 옷 nap
# under a dead elm dazzles the meadow
# where the partisans strung the traitors up,
#
# the meadow which their dangling shadows stain.
# Belly up in vines a blasted tank
# rusts flake by flake to lichened scrap iron
#
# while horseflies harangue
# the rippling green, July
# a limbo of quavering yellow...
#
# We wake to cattle lowing at dawn,
# grass overgrowing summer—so like us
# in love each hour with the noonday sun
#
# that neither toils nor spins, its brightness
# hovering, blinding us...
# What would the dead say if they could see us,
#
# lounging, talking, peering through brambles
# at cemetery photographs sunk beneath
# the undertow of milkweed shadows,
#
# death dates smoothing back into the stone?
# I think of Goya’s demon, old man flesh
# hanging from his bones, long teeth bared in
#
# an ass’s grin as he scrawls on a schoolboy’s
# slate, What more can be done? Nothing...
# while behind him a noose etched clean as
#
# ...

# %%
lyric = open("A forest").read()

# %%
print(lyric)
# Out:
# Come closer and see
# See into the trees
# Find the girl
# While you can
# Come closer and see
# See into the dark
# Just follow your eyes
# Just follow your eyes
# I hear her voice
# Calling my name
# The sound is deep
# In the dark
# I hear her voice
# And start to run
# Into the trees
# Into the trees
# Into the trees
# Suddenly I stop
# But I know it's too late
# I'm lost in a forest
# All alone
# The girl was never there
# It's always the same
# I'm running towards nothing
# Again and again and again and again...

# %%
print(poem[0:int(len(poem)/4)] + lyric[int(len(lyric)/3):len(lyric)])
# Out:
# Across the road from where we nap
# under a dead elm dazzles the meadow
# where the partisans strung the traitors up,
#
# the meadow which their dangling shadows stain.
# Belly up in vines a blasted tank
# rusts flake by flake to lichened scrap iron
#
# while horseflies harangue
# the rippling green, July
# a limbo of quavering yellow...
#
# We wake to cattle lowing at dawn,
# grass overgrowing summer—so like us
# in love each hour with the noonday sun
#
# that neither toils nor spins, its brightness
# hovering, blinding us...
# What would the dead say if they could see us,
#
# lounging, talking, peering through brambles
# at cemetery photographs sunk benr voice
# Calling my name
# The sound is deep
# In the dark
# I hear her voice
# And start to run
# Into the trees
# Into the trees
# Into the trees
# Suddenly I stop
# But I know it's too late
# I'm lost in a forest
# All alone
# The girl was never there
# It's always the same
# I'm running towards nothing
# ...

# %%
verse = poem[0:int(len(poem)/4)] + lyric[int(len(lyric)/3):len(lyric)]

# %%
print(verse)
# Out:
# Across the road from where we nap
# under a dead elm dazzles the meadow
# where the partisans strung the traitors up,
#
# the meadow which their dangling shadows stain.
# Belly up in vines a blasted tank
# rusts flake by flake to lichened scrap iron
#
# while horseflies harangue
# the rippling green, July
# a limbo of quavering yellow...
#
# We wake to cattle lowing at dawn,
# grass overgrowing summer—so like us
# in love each hour with the noonday sun
#
# that neither toils nor spins, its brightness
# hovering, blinding us...
# What would the dead say if they could see us,
#
# lounging, talking, peering through brambles
# at cemetery photographs sunk benr voice
# Calling my name
# The sound is deep
# In the dark
# I hear her voice
# And start to run
# Into the trees
# Into the trees
# Into the trees
# Suddenly I stop
# But I know it's too late
# I'm lost in a forest
# All alone
# The girl was never there
# It's always the same
# I'm running towards nothing
# ...

# %%
print(verse.replace("we ", "옷 "))
print(verse.replace("trees", "木"))
print(verse.replace("I ", "옷 "))
# Out:
# Across the road from where 옷 nap
# under a dead elm dazzles the meadow
# where the partisans strung the traitors up,
#
# the meadow which their dangling shadows stain.
# Belly up in vines a blasted tank
# rusts flake by flake to lichened scrap iron
#
# while horseflies harangue
# the rippling green, July
# a limbo of quavering yellow...
#
# We wake to cattle lowing at dawn,
# grass overgrowing summer—so like us
# in love each hour with the noonday sun
#
# that neither toils nor spins, its brightness
# hovering, blinding us...
# What would the dead say if they could see us,
#
# lounging, talking, peering through brambles
# at cemetery photographs sunk benr voice
# Calling my name
# The sound is deep
# In the dark
# I hear her voice
# And start to run
# Into the trees
# Into the trees
# Into the trees
# Suddenly I stop
# But I know it's too late
# I'm lost in a forest
# All alone
# The girl was never there
# It's always the same
# I'm running towards nothing
# ...
